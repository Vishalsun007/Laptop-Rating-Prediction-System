# %%
import pandas as pd

# Replace 'file_path.csv' with the path to your dataset
df = pd.read_excel('DataSet.xlsx')

# Display the first 5 rows of the dataframe
print(df.head())
# Out:
#    index   brand                                              Model  Price  \
# 0      1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1      2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2      3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD @ 560...  51100
# 3      4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4      5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
#
#    Rating processor_brand processor_tier  num_cores  num_threads  ram_memory  \
# 0      63           intel        core i3          2            4           8
# 1      67           intel        core i7          4            8          16
# 2      73             amd              @          6           12           8
# 3      62           intel        core i5         12           16           8
# 4      62             amd        ryzen 3          4            8           8
#
# ...

# %%
print(df.loc[22])
# Out:
# index                                                                        23
# brand                                                                         @
# Model                         @ MacBook Pro 16 2023 Laptop (@ M3 Max/ 48GB/ ...
# Price                                                                         ?
# Rating                                                                       65
# processor_brand                                                               @
# processor_tier                                                               m3
# num_cores                                                                    16
# num_threads                                                                  16
# ram_memory                                                                    8
# primary_storage_type                                                        SSD
# primary_storage_capacity                                                   1024
# ...

# %%
print(df['brand'].str.count('@').sum())

df['brand'] = df['brand'].replace('@', 'apple')
# Out:
# 15

# %%
df.head()
# Out:
#    index   brand                                              Model  Price  \
# 0      1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1      2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2      3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD @ 560...  51100
# 3      4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4      5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
#
#    Rating processor_brand processor_tier  num_cores  num_threads  ram_memory  \
# 0      63           intel        core i3          2            4           8
# 1      67           intel        core i7          4            8          16
# 2      73             amd              @          6           12           8
# 3      62           intel        core i5         12           16           8
# 4      62             amd        ryzen 3          4            8           8
#
# ...

# %%
print(df.loc[22])
# Out:
# index                                                                        23
# brand                                                                     apple
# Model                         @ MacBook Pro 16 2023 Laptop (@ M3 Max/ 48GB/ ...
# Price                                                                         ?
# Rating                                                                       65
# processor_brand                                                               @
# processor_tier                                                               m3
# num_cores                                                                    16
# num_threads                                                                  16
# ram_memory                                                                    8
# primary_storage_type                                                        SSD
# primary_storage_capacity                                                   1024
# ...

# %%
num_strings = df['Price'].apply(lambda x: isinstance(x, str)).sum()
print(num_strings)
# Out:
# 69

# %%
# Exclude the specified columns
excluded_columns = ['index', 'Price', 'Model', 'Rating']
included_columns = [col for col in df.columns if col not in excluded_columns]

# Print count and distinct values for each included column
for col in included_columns:
    print(f"Column: {col}")
    print("Count of distinct values:", df[col].nunique())
    print("Distinct values:", df[col].unique())
    print()
# Out:
# Column: brand
# Count of distinct values: 26
# Distinct values: ['tecno' 'hp' 'acer' 'lenovo' 'apple' 'infinix' 'asus' 'dell' 'samsung'
#  'msi' 'wings' 'ultimus' 'primebook' 'iball' 'zebronics' 'chuwi'
#  'gigabyte' 'jio' 'honor' 'realme' 'avita' 'microsoft' 'fujitsu' 'lg'
#  'walker' 'axl']
#
# Column: processor_brand
# Count of distinct values: 4
# Distinct values: ['intel' 'amd' '@' 'other']
#
# Column: processor_tier
# Count of distinct values: 15
# Distinct values: ['core i3' 'core i7' '@' 'core i5' 'ryzen 3' 'm1' 'core i9' 'ryzen 7'
#  'other' 'm3' 'm2' 'ryzen 9' 'celeron' 'core ultra 7' 'pentium']
#
# Column: num_cores
# Count of distinct values: 12
# Distinct values: [ 2  4  6 12  8 14 20 10 16 24  5 11]
#
# Column: num_threads
# Count of distinct values: 15
# Distinct values: [ 4  8 12 16 20 28  2 32 24  0  6 22 14 11  5]
#
# Column: ram_memory
# Count of distinct values: 7
# Distinct values: [ 8 16 32  4  2 12 36]
#
# Column: primary_storage_type
# ...

# %%
count_no_info = df['year_of_warranty'].value_counts().get('No information', 0)
print(count_no_info)
# Out:
# 0

# %%
df['year_of_warranty'] = df['year_of_warranty'].replace('No information', 1)

# %%
print("Count of distinct values in resolution_height:")
print(df['resolution_height'].value_counts())

print("\nCount of distinct values in resolution_width:")
print(df['resolution_width'].value_counts())
# Out:
# Count of distinct values in resolution_height:
# resolution_height
# 1080    648
# #       128
# 1600     64
# 768      52
# 1800     34
# 1440     16
# 1920     10
# 2000      7
# 1620      6
# 1964      4
# 2234      4
# 2160      3
# 1024      3
# 1864      2
# 1664      2
# 2400      2
# 1504      1
# 1660      1
# 800       1
# 1536      1
# $         1
# 1400      1
# Name: count, dtype: int64
#
# Count of distinct values in resolution_width:
# resolution_width
# 1920    776
# $       134
# 2880     37
# 3200      8
# 1080      7
# 3456      6
# 3024      4
# 3000      4
# 2160      2
# 1536      2
# #         2
# 3840      2
# 1440      1
# 2048      1
# 2256      1
# 1280      1
# 1600      1
# 2240      1
# 3072      1
# Name: count, dtype: int64

# %%
def calculate_width(value, height):
    if isinstance(value, int):
        return value
    else:
        return int((16/9) * height)

df['resolution_width'] = df.apply(lambda row: calculate_width(row['resolution_width'], row['resolution_height']), axis=1)

# %%
print("\nCount of distinct values in resolution_width:")
print(df['resolution_width'].value_counts())
# Out:
# Count of distinct values in resolution_height:
# resolution_height
# 1080    776
# 1600     64
# 768      52
# 1800     34
# 1440     16
# 1920     10
# 2000      7
# 1620      6
# 1964      4
# 2234      4
# 2160      3
# 1024      3
# 1864      2
# 1664      2
# 2400      2
# 1504      1
# 1660      1
# 800       1
# 1536      1
# 900       1
# 1400      1
# Name: count, dtype: int64
#
# Count of distinct values in resolution_width:
# resolution_width
# 1920    776
# 2844     64
# 1365     52
# 2880     37
# 2560     14
# 3200      8
# 1080      7
# 3456      6
# 3024      4
# 3000      4
# 1536      2
# 3840      2
# 2958      2
# 3413      2
# 2160      2
# 2240      1
# 1600      1
# 1280      1
# 2951      1
# 2048      1
# 1440      1
# 1422      1
# 2256      1
# 3072      1
# Name: count, dtype: int64

# %%
def calculate_height(value, width):
    if isinstance(value, int):
        return value
    else:
        return int((9/16) * width)

df['resolution_height'] = df.apply(lambda row: calculate_height(row['resolution_height'], row['resolution_width']), axis=1)

# %%
print("Count of distinct values in resolution_height:")
print(df['resolution_height'].value_counts())
# Out:
# Count of distinct values in resolution_height:
# resolution_height
# 1080    776
# 1600     64
# 768      52
# 1800     34
# 1440     16
# 1920     10
# 2000      7
# 1620      6
# 1964      4
# 2234      4
# 2160      3
# 1024      3
# 1864      2
# 1664      2
# 2400      2
# 1504      1
# 1660      1
# 800       1
# 1536      1
# 900       1
# 1400      1
# Name: count, dtype: int64

# %%
df['gpu_type'] = df['gpu_type'].replace('@', 'other')

# %%
print("Count of distinct values in gpu_type:")
print(df['gpu_type'].value_counts())
# Out:
# Count of distinct values in gpu_type:
# gpu_type
# integrated    605
# dedicated     353
# other          33
# Name: count, dtype: int64

# %%
df['gpu_brand'] = df['gpu_brand'].replace('@', 'amd')

# %%
print(df['gpu_brand'].nunique())
print(df['gpu_brand'].unique())
# Out:
# 4
# ['intel' 'amd' 'nvidia' 'arm']

# %%
df = df.drop(columns=['secondary_storage_type'])

# %%
df.head()
# Out:
#    index   brand                                              Model  Price  \
# 0      1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...  23990
# 1      2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...  35990
# 2      3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD @ 560...  51100
# 3      4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...  39990
# 4      5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...  28580
#
#    Rating processor_brand processor_tier  num_cores  num_threads  ram_memory  \
# 0      63           intel        core i3          2            4           8
# 1      67           intel        core i7          4            8          16
# 2      73             amd              @          6           12           8
# 3      62           intel        core i5         12           16           8
# 4      62             amd        ryzen 3          4            8           8
#
# ...

# %%
count_no_value_price = df['Price'].apply(lambda x: not isinstance(x, int)).sum()
print(count_no_value_price)
# Out:
# 69

# %%
print("Count of distinct values in processor_tier:")
print(df['processor_tier'].value_counts())
# Out:
# Count of distinct values in processor_tier:
# processor_tier
# core i5         335
# core i7         159
# @               139
# core i3         127
# ryzen 7          77
# celeron          40
# core i9          37
# ryzen 3          31
# other            14
# ryzen 9          12
# m3                8
# m2                6
# core ultra 7      3
# pentium           2
# m1                1
# Name: count, dtype: int64

# %%
# Calculate the average of integer values in the 'Price' column
average_price = df[df['Price'].apply(lambda x: isinstance(x, int))]['Price'].mean()

# Replace non-integer values with the average
df['Price'] = df['Price'].apply(lambda x: average_price if not isinstance(x, int) else x)

# %%
count_no_value_price = df['Price'].apply(lambda x: not isinstance(x, int)).sum()
print(count_no_value_price)
# Out:
# 991

# %%
df
# Out:
#      index   brand                                              Model  \
# 0        1   tecno  Tecno Megabook T1 Laptop (11th Gen Core i3/ 8G...
# 1        2   tecno  Tecno Megabook T1 Laptop (11th Gen Core i7/ 16...
# 2        3      hp  HP Victus 15-fb0157AX Gaming Laptop (AMD @ 560...
# 3        4    acer  Acer Extensa EX214-53 Laptop (12th Gen Core i5...
# 4        5  lenovo  Lenovo V15 82KDA01BIH Laptop (AMD Ryzen 3 5300...
# ..     ...     ...                                                ...
# 986    998    asus  Asus Vivobook Pro 15 M6500QC-HN542WS Laptop (@...
# 987    999     msi  MSI Thin GF63 12VE-070IN Gaming Laptop (12th G...
# 988   1000    asus  Asus Vivobook Go 15 2023 E1504FA-NJ522WS Lapto...
# 989   1001    asus  Asus Zenbook 14 2023 UM3402YA-KP541WS Laptop (...
# 990   1002      hp  HP Chromebook 15a-na0008TU Laptop (Intel Celer...
#
#        Price  Rating processor_brand processor_tier  num_cores  num_threads  \
# ...

# %%
df['Price'] = df['Price'].astype(int)

# %%
count_no_value_price = df['Price'].apply(lambda x: not isinstance(x, int)).sum()
print(count_no_value_price)
# Out:
# 0

# %%
print("Distinct model types with count:")
print(df['Model'].value_counts())
# Out:
# Distinct model types with count:
# Model
# Tecno Megabook T1 Laptop (11th Gen Core i3/ 8GB/ 512GB SSD/ Win11 Home)                                 1
# Asus Vivobook 15 OLED 2023 X1505VAU-LK543WS Laptop (13th Gen Core i5/ 16GB/ 512GB SSD/ Win11 Home)      1
# Lenovo IdeaPad Gaming 3 82K101LHIN Laptop (11th Gen Core i5/ 16GB/ 512GB SSD/ Win11 Home/ 4GB Graph)    1
# Asus Vivobook 15 2023 X1504VA-NJ543WS Laptop (13th Gen Core i5/ 16GB/ 512GB SSD/ Win11)                 1
# Lenovo ThinkPad E14 21JRS00T00 Laptop (AMD @ 7530U/ 8GB/ 512GB SSD/ Win11 Home)                         1
#                                                                                                        ..
# HP ProBook 440 G9 821M3PA Laptop (12th Gen Core i5/ 8GB/ 512GB SSD/ Win11)                              1
# HP 15s-FR5012TU Laptop (12th Gen Core i3/ 8GB/ 512GB SSD/ Win11 Home)                                   1
# ...

# %%
df['Model'] = df['Model'].str.replace(r"\(.*\)", "", regex=True)

# %%
print("Distinct model types with count:")
print(df['Model'].value_counts())
# Out:
# Distinct model types with count:
# Model
# @ MacBook Pro 14 2023 Laptop                         4
# @ MacBook Pro 16 2023 Laptop                         4
# Tecno Megabook T1 Laptop                             2
# Chuwi CoreBook X Laptop                              2
# Dell Inspiron 3535 Laptop                            2
#                                                     ..
# Asus Vivobook Pro 15 OLED M6500QC-LK751WS Laptop     1
# MSI Vector GP68 HX 13VG-214IN Gaming Laptop          1
# Dell G15-5530 15 2023 Gaming Laptop                  1
# Lenovo IdeaPad Flex 5 82R9008FIN Laptop              1
# HP Chromebook 15a-na0008TU Laptop                    1
# Name: count, Length: 967, dtype: int64

# %%
print("Total distinct types of models:", df['Model'].nunique())
# Out:
# Total distinct types of models: 967

# %%
df = df.drop(columns=['Model'])
# Out:
#      index   brand                                             Model  Price  \
# 0        1   tecno                         Tecno Megabook T1 Laptop   23990
# 1        2   tecno                         Tecno Megabook T1 Laptop   35990
# 2        3      hp              HP Victus 15-fb0157AX Gaming Laptop   51100
# 3        4    acer                     Acer Extensa EX214-53 Laptop   39990
# 4        5  lenovo                     Lenovo V15 82KDA01BIH Laptop   28580
# ..     ...     ...                                               ...    ...
# 986    998    asus      Asus Vivobook Pro 15 M6500QC-HN542WS Laptop   65990
# 987    999     msi           MSI Thin GF63 12VE-070IN Gaming Laptop   91990
# 988   1000    asus  Asus Vivobook Go 15 2023 E1504FA-NJ522WS Laptop   44990
# 989   1001    asus     Asus Zenbook 14 2023 UM3402YA-KP541WS Laptop   67990
# 990   1002      hp                HP Chromebook 15a-na0008TU Laptop   20990
#
# ...

# %%
print(df.dtypes)

# %%
df.head()
# Out:
#    index   brand  Price  Rating processor_brand processor_tier  num_cores  \
# 0      1   tecno  23990      63           intel        core i3          2
# 1      2   tecno  35990      67           intel        core i7          4
# 2      3      hp  51100      73             amd              @          6
# 3      4    acer  39990      62           intel        core i5         12
# 4      5  lenovo  28580      62             amd        ryzen 3          4
#
#    num_threads  ram_memory primary_storage_type  primary_storage_capacity  \
# 0            4           8                  SSD                       512
# 1            8          16                  SSD                      1024
# 2           12           8                  SSD                       512
# 3           16           8                  SSD                       512
# 4            8           8                  SSD                       512
#
#    secondary_storage_capacity gpu_brand    gpu_type  is_touch_screen  \
# ...

# %%
df = df.drop(columns=['index'])

# %%
df.head()
# Out:
#     brand  Price  Rating processor_brand processor_tier  num_cores  \
# 0   tecno  23990      63           intel        core i3          2
# 1   tecno  35990      67           intel        core i7          4
# 2      hp  51100      73             amd              @          6
# 3    acer  39990      62           intel        core i5         12
# 4  lenovo  28580      62             amd        ryzen 3          4
#
#    num_threads  ram_memory primary_storage_type  primary_storage_capacity  \
# 0            4           8                  SSD                       512
# 1            8          16                  SSD                      1024
# 2           12           8                  SSD                       512
# 3           16           8                  SSD                       512
# 4            8           8                  SSD                       512
#
#    secondary_storage_capacity gpu_brand    gpu_type  is_touch_screen  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create a copy of the dataframe
df_encoded = df.copy()

# Create a LabelEncoder object
le = LabelEncoder()

# Apply LabelEncoder to each column of the dataframe
for col in df_encoded.columns:
    if df_encoded[col].dtype == 'object':
        df_encoded[col] = le.fit_transform(df_encoded[col])

# %%
# Assuming df is the DataFrame you are working with
encoding_dict = {}

# Select only columns of type object
object_cols = df.select_dtypes(include=['object']).columns

# For each column, fit a LabelEncoder, transform the data and store in the dictionary
for col in object_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoding_dict[col] = dict(zip(le.classes_, le.transform(le.classes_)))

encoding_dict
# Out:
# {'brand': {'acer': 0,
#   'apple': 1,
#   'asus': 2,
#   'avita': 3,
#   'axl': 4,
#   'chuwi': 5,
#   'dell': 6,
#   'fujitsu': 7,
#   'gigabyte': 8,
#   'honor': 9,
#   'hp': 10,
#   'iball': 11,
#   'infinix': 12,
#   'jio': 13,
#   'lenovo': 14,
#   'lg': 15,
#   'microsoft': 16,
#   'msi': 17,
#   'primebook': 18,
#   'realme': 19,
#   'samsung': 20,
#   'tecno': 21,
#   'ultimus': 22,
#   'walker': 23,
#   'wings': 24,
#   'zebronics': 25},
#  'processor_brand': {'@': 0, 'amd': 1, 'intel': 2, 'other': 3},
#  'processor_tier': {'@': 0,
#   'celeron': 1,
#   'core i3': 2,
#   'core i5': 3,
#   'core i7': 4,
#   'core i9': 5,
#   'core ultra 7': 6,
#   'm1': 7,
#   'm2': 8,
#   'm3': 9,
#   'other': 10,
#   'pentium': 11,
#   'ryzen 3': 12,
#   'ryzen 7': 13,
#   'ryzen 9': 14},
#  'primary_storage_type': {'HDD': 0, 'SSD': 1},
#  'gpu_brand': {'amd': 0, 'arm': 1, 'intel': 2, 'nvidia': 3},
#  'gpu_type': {'dedicated': 0, 'integrated': 1, 'other': 2},
#  'OS': {'android': 0,
# ...

# %%
df_encoded
# Out:
#      brand  Price  Rating  processor_brand  processor_tier  num_cores  \
# 0       21  23990      63                2               2          2
# 1       21  35990      67                2               4          4
# 2       10  51100      73                1               0          6
# 3        0  39990      62                2               3         12
# 4       14  28580      62                1              12          4
# ..     ...    ...     ...              ...             ...        ...
# 986      2  65990      68                1               0          6
# 987     17  91990      73                2               4         10
# 988      2  44990      59                1               0          4
# 989      2  67990      68                1               0          6
# 990     10  20990      37                2               1          2
#
#      num_threads  ram_memory  primary_storage_type  primary_storage_capacity  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(25,25))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Random Forest

# %%
from sklearn.model_selection import GridSearchCV
# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300, 400, 500],
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 10, 20, 30, 40, 50]
}

# Create a GridSearchCV object
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid, cv=5)

# Fit the GridSearchCV object to the data
grid_search.fit(X_train, y_train)

# Get the best parameters
best_params = grid_search.best_params_

# Create a new RandomForestClassifier with the best parameters
clf = RandomForestClassifier(**best_params, random_state=42)

# Train the new model
clf.fit(X_train, y_train)

# Make predictions
y_pred = clf.predict(X_test)

# Evaluate the new model
accuracy = accuracy_score(y_test, y_pred)
print(f"Model accuracy: {accuracy}")
# Out:
# c:\Users\Rajkumar\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_split.py:737: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# Model accuracy: 0.15577889447236182

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize the DecisionTreeClassifier
dt = DecisionTreeClassifier(random_state=42)

# Fit the model on the training data
dt.fit(X_train, y_train)

# Predict the labels of the test set
y_pred = dt.predict(X_test)

# Calculate the accuracy of the model
accuracy_dt = accuracy_score(y_test, y_pred)

print("Accuracy of Decision Tree: ", accuracy_dt)
# Out:
# Accuracy of Decision Tree:  0.12562814070351758

# %%
# Use the RandomForestClassifier to fit the model
clf.fit(X_train, y_train)

# Predict the test set results
y_pred = clf.predict(X_test)

# Calculate the accuracy of the model
accuracy_rf = accuracy_score(y_test, y_pred)

print("Accuracy of Random Forest: ", accuracy_rf)
# Out:
# Accuracy of Random Forest:  0.15577889447236182

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Create a Linear Regression model
lr = LinearRegression()

# Fit the model with the training data
lr.fit(X_train, y_train)

# Predict the target on the train dataset
predict_train = lr.predict(X_train)

# Predict the target on the test dataset
predict_test = lr.predict(X_test)

# Calculate the accuracy of the Linear Regression model
lr_accuracy = r2_score(y_test, predict_test)

print("Linear Regression Accuracy: ", lr_accuracy)
# Out:
# Linear Regression Accuracy:  0.8271694689428696

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# create an instance of StandardScaler
scaler = StandardScaler()

# fit and transform the training data
X_train_scaled = scaler.fit_transform(X_train)

# transform the test data
X_test_scaled = scaler.transform(X_test)

# create an instance of LogisticRegression with increased max_iter
logreg = LogisticRegression(max_iter=1000)

# fit the model with scaled data
logreg.fit(X_train_scaled, y_train)

# predict the response values for the observations in X_test
y_pred = logreg.predict(X_test_scaled)

# compute classification accuracy for the logistic regression model
accuracy_logreg = accuracy_score(y_test, y_pred)

print(f'Accuracy of logistic regression classifier on test set: {accuracy_logreg}')
# Out:
# Accuracy of logistic regression classifier on test set: 0.09547738693467336

# %%
from sklearn.metrics import r2_score

# make predictions on the test data
predictions_svr = svr.predict(X_test_scaled)

# calculate the R^2 score of the model
r2_score_svr = r2_score(y_test, predictions_svr)

print("R^2 Score of SVR: ", r2_score_svr)
# Out:
# R^2 Score of SVR:  0.6439971414878963

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Create a Linear Regression object
linear_regression = LinearRegression()

# Fit the model using the training data
linear_regression.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = linear_regression.predict(X_test)

# The coefficients
print('Coefficients: \n', linear_regression.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Calculate the accuracy of the model
accuracy = linear_regression.score(X_test, y_test)
print('Accuracy: %.2f' % accuracy)
# Out:
# Coefficients:
#  [ 9.02440883e-02  2.40002657e-05  3.86679216e-01  8.09180601e-02
#  -1.19097897e+00  1.43365025e+00  2.43785849e-01  4.48636173e+00
#   3.35549005e-03  1.20030054e-02  1.00006866e+00 -2.62105388e+00
#   3.37521730e+00  5.91774074e-01  2.10077647e-03 -1.71744186e-04
#   1.21879637e+00  1.39438866e+00]
# Mean squared error: 20.66
# Coefficient of determination: 0.83
# Accuracy: 0.83

# %%
from sklearn.neighbors import KNeighborsClassifier

# Create a KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)

# Train the classifier using the training data
knn.fit(X_train_scaled, y_train)

# Predict the labels of the test set
y_pred = knn.predict(X_test_scaled)

# Calculate the accuracy of the model
accuracy_knn = accuracy_score(y_test, y_pred)

print("Accuracy of KNN: ", accuracy_knn)
# Out:
# Accuracy of KNN:  0.07537688442211055

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Initialize Ridge Regression model
ridge = Ridge()

# Fit the model
ridge.fit(X_train_scaled, y_train)

# Predict the test set results
y_pred_ridge = ridge.predict(X_test_scaled)

# Calculate the Mean Squared Error of the predictions
mse_ridge = mean_squared_error(y_test, y_pred_ridge)

print("Mean Squared Error of Ridge Regression: ", mse_ridge)
# Calculate the accuracy
accuracy_ridge = ridge.score(X_test_scaled, y_test)

print("Accuracy of Ridge Regression: ", accuracy_ridge)
# Out:
# Mean Squared Error of Ridge Regression:  20.66144614873157
# Accuracy of Ridge Regression:  0.8271203952338444

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import make_pipeline

# Define the degree of the polynomial features
degree = 2

# Create a pipeline that first transforms the features into polynomial features, then applies linear regression
polyreg = make_pipeline(PolynomialFeatures(degree), LinearRegression())

# Fit the model
polyreg.fit(X_train, y_train)

# Predict on the test set
y_pred = polyreg.predict(X_test)

# Calculate the R-squared score, which is a measure of how well the model fits the data
r2 = r2_score(y_test, y_pred)

print(f"R-squared score: {r2}")
# Out:
# R-squared score: 0.7715456244878102

# %%
from sklearn.metrics import mean_squared_error, r2_score
from joblib import dump

# Create a Linear Regression object
linear_regression = LinearRegression()

# Fit the model using the training data
linear_regression.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = linear_regression.predict(X_test)

# The coefficients
print('Coefficients: \n', linear_regression.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))
# Calculate the accuracy of the model
accuracy = linear_regression.score(X_test, y_test)
print('Accuracy: %.2f' % accuracy)
# Out:
# Coefficients:
#  [ 9.02440883e-02  2.40002657e-05  3.86679216e-01  8.09180601e-02
#  -1.19097897e+00  1.43365025e+00  2.43785849e-01  4.48636173e+00
#   3.35549005e-03  1.20030054e-02  1.00006866e+00 -2.62105388e+00
#   3.37521730e+00  5.91774074e-01  2.10077647e-03 -1.71744186e-04
#   1.21879637e+00  1.39438866e+00]
# Mean squared error: 20.66
# Coefficient of determination: 0.83
# Accuracy: 0.83

# %%
from joblib import dump

# Save the model to a file
dump(linear_regression, 'linear_regression_model.joblib')
# Out:
# ['linear_regression_model.joblib']

# %%
df_encoded
# Out:
#      brand  Price  Rating  processor_brand  processor_tier  num_cores  \
# 0       21  23990      63                2               2          2
# 1       21  35990      67                2               4          4
# 2       10  51100      73                1               0          6
# 3        0  39990      62                2               3         12
# 4       14  28580      62                1              12          4
# ..     ...    ...     ...              ...             ...        ...
# 986      2  65990      68                1               0          6
# 987     17  91990      73                2               4         10
# 988      2  44990      59                1               0          4
# 989      2  67990      68                1               0          6
# 990     10  20990      37                2               1          2
#
#      num_threads  ram_memory  primary_storage_type  primary_storage_capacity  \
# ...
